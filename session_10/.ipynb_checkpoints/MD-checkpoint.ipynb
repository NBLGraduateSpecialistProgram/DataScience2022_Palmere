# %% [markdown]
# ##### Molecular Dynamics with Python
# Robert Palmere\
# email: rdp135@chem.rutgers.edu

# %% [markdown]
# We will be reviewing chapter 2 from "The Art of Molecular Dynamics" by D.C. Rapaport (https://doi.org/10.1021/ed076p171).
#
# The code presented in this book is written in C so we will modify some of the functions to be suitable for Python. The names of variables and function names are kept similar if not the same.
#
# Objective: To use what we have covered in previous sessions to carry out simplified molecular dynamics

# %%
import numpy as np

class MD(object):
    def __init__(self, fn):
        self.fn = fn
        self.namelist = {'runId' : None,
                         'initUcell' : None,
                         'density' : None,
                         'temperature' : None,
                         'deltaT' : None,
                         'randSeed' : None,
                         'stepAvg' : None,
                         'stepEquil' : None,
                         'stepLimit' : None }
        
    def get_name_list(self):
        """ Function to read simulation parameters into namelist dictionary
        """
        with open(self.fn, 'r') as fp:
            lines = fp.readlines()
            for n, l in enumerate(lines):
                if l.split()[0] != 'initUcell':
                    self.namelist[l.split()[0]] = float(l.split()[1])
                else:
                    self.namelist[l.split()[0]] = [float(l.split()[1]), float(l.split()[2])]
                
        return self.namelist
    
    def set_params(self):
        pass
    
    def setup_job(self):
        pass
        
        # Nested Functions:
        #     AllocArrays()
        #      InitCoords()
        #       InitVels ()
        #     AccumProps(0)
        #    stepCount = 0
    
    def single_step(self):
        pass
    
        # Nested Functions:
        #      stepCount = stepCount + 1
        #   timeNow = stepCount * deltaT
        #                ComputeForces()
        #                 LeapfrogStep()
        #            ApplyBoundaryCond()
        #                    EvalProps()
        #                  AccumProps(1)
        #  if (stepCount % stepAvg == 0)
        #      AccumProps(2)
        #      PrintSummary()
        #      AccumProps

# %%
print(MD('input').get_name_list())
# Out:
# {'runId': 1.0, 'initUcell': [20.0, 20.0], 'density': 0.8, 'temperature': 1.0, 'deltaT': 0.005, 'randSeed': 17.0, 'stepAvg': 100.0, 'stepEquil': 0.0, 'stepLimit': 25.0}

# %% [markdown]
# Now that we have mapped out our class, let's go ahead and define the others in an iterative fashion.

# %%
class MD(object):
    """ Class to perform simple molecular dynamics
    < Params >
    """
    def __init__(self, fn):
        self.fn = fn
        self.namelist = {'runId' : None,
                         'initUcell' : None,
                         'density' : None,
                         'temperature' : None,
                         'deltaT' : None,
                         'randSeed' : None,
                         'stepAvg' : None,
                         'stepEquil' : None,
                         'stepLimit' : None }
        
        # Simulation Parameters
        
        self.ndim = 2
        self.natom = None
        self.vmag = None
        self.region = np.empty(self.ndim)
        self.regionH = np.empty(self.ndim)
        
    def get_name_list(self):
        """ Function to read simulation parameters into namelist dictionary
        """
        with open(self.fn, 'r') as fp:
            lines = fp.readlines()
            for n, l in enumerate(lines):
                if l.split()[0] != 'initUcell':
                    self.namelist[l.split()[0]] = float(l.split()[1])
                else:
                    self.namelist[l.split()[0]] = [float(l.split()[1]), float(l.split()[2])]
                
        return self.namelist
    
    def set_params(self):
        """ < Function description here >
        """
        for i in range(self.ndim):
            self.region[i] =  self.namelist['initUcell'][i] / np.sqrt(self.namelist['density'])
            self.regionH[i] = self.region[i] / 2.0
        self.natom = self.namelist['initUcell'][0] * self.namelist['initUcell'][1]
        self.vmag = np.sqrt(self.ndim * (1. - (1. / self.natom)) * self.namelist['temperature'])

# %% [markdown]
# Now we test to see if set_params() actually sets the desired parameters.

# %%
test = MD('input')
test.get_name_list()
test.set_params()

print(f"Edge lengths of simulation region: {test.region}")
print(f"Half Edge lengths of simulation region: {test.regionH}" ) # Separate allocation for half region is due to frequency of use
print(f"Number of atoms in grid formation: {test.natom}")
print(f"Velocities set to: {test.vmag}")
# Out:
# Edge lengths of simulation region: [22.36067977 22.36067977]
# Half Edge lengths of simulation region: [11.18033989 11.18033989]
# Number of atoms in grid formation: 400.0
# Velocities set to: 1.4124446891825535

# %% [markdown]
# Now that we have our initial state from our input file, we can move on to defining a single step of dynamics.

# %%
class MD(object):
    """ Class to perform simple molecular dynamics
    < Params >
    """
    def __init__(self, fn):
        self.fn = fn
        self.namelist = {'runId' : None,
                         'initUcell' : None,
                         'density' : None,
                         'temperature' : None,
                         'deltaT' : None,
                         'randSeed' : None,
                         'stepAvg' : None,
                         'stepEquil' : None,
                         'stepLimit' : None }
        
        # Simulation Parameters
        
        self.step_count = 0
        self.time_now = 0
        self.ndim = 2
        self.natom = None
        self.vmag = 100
        self.region = np.empty(self.ndim)
        self.regionH = np.empty(self.ndim)
        self.rcut = 1
        
        # Position, Velocities, and Acceleration
        
        self.r = None
        self.rv = None
        self.ra = None
        self.vsum = None
        
        
    def get_name_list(self):
        """ Function to read simulation parameters into namelist dictionary
        
        Parameters
        ----------
        
        n.a.
        
        """
        with open(self.fn, 'r') as fp:
            lines = fp.readlines()
            for n, l in enumerate(lines):
                if l.split()[0] != 'initUcell':
                    self.namelist[l.split()[0]] = float(l.split()[1])
                else:
                    self.namelist[l.split()[0]] = [float(l.split()[1]), float(l.split()[2])]
                
        return self.namelist
    
    def set_params(self):
        """ Set parameters not included in input
        """
        for i in range(self.ndim):
            self.region[i] =  self.namelist['initUcell'][i] / np.sqrt(self.namelist['density'])
            self.regionH[i] = self.region[i] / 2.0
        self.natom = self.namelist['initUcell'][0] * self.namelist['initUcell'][1]
        self.vmag = np.sqrt(self.ndim * (1. - (1. / self.natom)) * self.namelist['temperature'])     
    
    def init_coords(self):
        """ Preparation of initial state for atomic coordinates (2D grid)
        Note - This can also be done using np.meshgrid or the like
        
        Parameters
        ----------
        
        n.a.
        
        """
        
        self.r = np.empty((self.ndim, int(self.natom)))
        gap = np.empty(self.ndim)
        c = np.empty(self.ndim)
        for k in range(self.ndim):
            gap[k] = self.region[k] / self.namelist['initUcell'][k]
        
        n = -1
        for nY in range(int(self.namelist['initUcell'][1])):
            
            c[1] = (nY - 0.5) * gap[1] - self.regionH[1]
            for nX in range(int(self.namelist['initUcell'][0])):
                c[0] = (nX - 0.5) * gap[0] - self.regionH[0]
                n += 1
                for k in range(self.ndim):
                    self.r[k][n] = c[k]
                
    
    def init_vels(self):
        """ Preparation of initial state for atomic velocities
        
        Parameters
        ----------
        
        n.a.
        
        """
        self.rv = np.empty((self.ndim, int(self.natom)))
        self.vsum = np.empty(self.ndim)
        
        for k in range(self.ndim):
            if k == 0:
                self.vsum[k] = 0. # zero initialize
            for n in range(int(self.natom)):
                ang = 2. * np.pi * np.random.rand(1)
                self.rv[0][n] = self.vmag * np.cos(ang)
                self.rv[1][n] = self.vmag * np.sin(ang)
                for k in range(self.ndim):
                    self.vsum[k] = self.vsum[k] + self.rv[k][n]
                
        for k in range(self.ndim):
            self.vsum[k] = self.vsum[k] / self.natom
            for n in range(int(self.natom)):
                self.rv[k][n] = self.rv[k][n] - self.vsum[k]

# %% [markdown]
# Now let's visually assess the initial state of our system.

# %%
import matplotlib.pyplot as plt

test = MD('input')
test.get_name_list()
test.set_params()
test.init_coords()
test.init_vels()

fig, ax = plt.subplots()

ax.scatter(test.r[0, :], test.r[1, :], c='k')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let's add functions to our class to perform computations for atomic dynamics.

# %%
class MD(object):
    """ Class to perform simple molecular dynamics
    < Params >
    """
    def __init__(self, fn):
        self.fn = fn
        self.namelist = {'runId' : None,
                         'initUcell' : None,
                         'density' : None,
                         'temperature' : None,
                         'deltaT' : None,
                         'randSeed' : None,
                         'stepAvg' : None,
                         'stepEquil' : None,
                         'stepLimit' : None }
        
        # Simulation Parameters
        
        self.step_count = 0
        self.time_now = 0
        self.ndim = 2
        self.natom = None
        self.vmag = None
        self.region = np.empty(self.ndim)
        self.regionH = np.empty(self.ndim)
        self.rcut = 0.3
        
        # Position, Velocities, Acceleration, and Energies
        
        self.r = None
        self.rv = None
        self.ra = None
        self.vsum = None
        self.vvsum = 0
        self.usum = 0
        self.virsum = 0
        self.kinenergy = 0
        self.potenergy = 0
        self.totenergy = 0
        self.pressure = 0
        
        
    def get_name_list(self):
        """ Read simulation parameters into namelist dictionary
        
        Parameters
        ----------
        
        n.a.
        
        """
        with open(self.fn, 'r') as fp:
            lines = fp.readlines()
            for n, l in enumerate(lines):
                if l.split()[0] != 'initUcell':
                    self.namelist[l.split()[0]] = float(l.split()[1])
                else:
                    self.namelist[l.split()[0]] = [float(l.split()[1]), float(l.split()[2])]
                
        return self.namelist
    
    def set_params(self):
        """ Set t
        """
        self.rcut = pow(2., 1./6.)
        for k in range(self.ndim):
            self.region[k] =  self.namelist['initUcell'][k] / np.sqrt(self.namelist['density'])
            self.regionH[k] = self.region[k] * 0.5
        self.natom = int(self.namelist['initUcell'][0] * self.namelist['initUcell'][1])
        self.vmag = np.sqrt(self.ndim * (1. - (1. / self.natom)) * self.namelist['temperature'])   
        
    def alloc_arrays(self):
        self.r = np.empty((self.ndim, int(self.natom)))
        self.rv = np.empty((self.ndim, int(self.natom)))
        self.ra = np.zeros((self.ndim, int(self.natom)))
    
    def init_coords(self):
        """ Preparation of initial state for atomic coordinates (2D grid)
        Note - This can also be done using np.meshgrid or the like
        
        Parameters
        ----------
        
        n.a.
        
        """
        
        gap = np.empty(self.ndim)
        c = np.empty(self.ndim)
        for k in range(self.ndim):
            gap[k] = self.region[k] / self.namelist['initUcell'][k]
        
        n = -1
        for nY in range(int(self.namelist['initUcell'][1])):
            
            c[1] = (nY - 0.5) * gap[1] - self.regionH[1]
            for nX in range(int(self.namelist['initUcell'][0])):
                c[0] = (nX - 0.5) * gap[0] - self.regionH[0]
                n += 1
                for k in range(self.ndim):
                    self.r[k][n] = c[k]
    
    def init_vels(self):
        """ Preparation of initial state for atomic velocities
        
        Parameters
        ----------
        
        n.a.
        
        """

        self.vsum = np.empty(self.ndim)
        np.random.seed(int(self.namelist['randSeed']))
        
        for k in range(self.ndim):
            if k == 0:
                self.vsum[k] = 0.
            for n in range(int(self.natom)):
                ang = 2. * np.pi * np.random.rand(1)
                self.rv[0][n] = self.vmag * np.cos(ang)
                self.rv[1][n] = self.vmag * np.sin(ang)
                for k in range(self.ndim):
                    self.vsum[k] = self.vsum[k] + self.rv[k][n]
                
        for k in range(self.ndim):
            self.vsum[k] = self.vsum[k] / self.natom
            for n in range(int(self.natom)):
                self.rv[k][n] = self.rv[k][n] - self.vsum[k]
                
    def signr(self, x, y):
        """ Reverse sign of x depending on y
        """
        if y >= 0.:
            return x
        else:
            return -x

    def compute_forces(self):
        """ Compute the forces of all interacting atom pairs < rcut 
        
        Parameters
        ----------
        
        n.a.
        
        """
        
        rrcut = self.rcut ** 2
        dr = np.empty(self.ndim)
        rr = 0
        rri = 0
        rri3 = 0
        fcval = 0
        
        self.usum = 0
        self.virsum = 0
        for j1 in range(int(self.natom)-1):
            for j2 in range(j1+1, int(self.natom)): # Note - Computing for all atom pairs (expensive)
                
                rr = 0
                for k in range(self.ndim):
                    dr[k] = self.r[k][j1] - self.r[k][j2]
                    
                    if (abs(dr[k]) > self.regionH[k]):
                        dr[k] = dr[k] - self.signr(self.region[k], dr[k])
                    rr = rr + (dr[k]**2)

                if (rr < rrcut):
                    rri = 1. / rr # As rr gets smaller, rri increases causing repulsion
                    rri3 = rri ** 3
                    fcval = 48. * rri3 * (rri3 - 0.5) * rri
                    for k in range(self.ndim):
                        f = fcval * dr[k] # setting F=0 will produce non-colliding particles
                        self.ra[k][j1] = self.ra[k][j1] + f
                        self.ra[k][j2] = self.ra[k][j2] - f
                    self.usum += 4. * rri3 * (rri3 - 1.) + 1. # Adds to potential energy
                                                              # but does nothing with it
                    self.virsum += (fcval * rr)

                    
    def leapfrog_step(self):
        """ Leap-frog step to the next state in phase space
        """
        for n in range(int(self.natom)):
            for k in range(self.ndim):
                self.rv[k][n] = self.rv[k][n] + self.namelist['deltaT'] * self.ra[k][n]
                self.r[k][n] = self.r[k][n] + self.namelist['deltaT'] * self.rv[k][n]
                
    def apply_boundary_cond(self):
        """ Apply boundary condition to all atoms by reversing their direction past region
        """
        
        for n in range(int(self.natom)):
            for k in range(self.ndim):
                if (self.r[k][n] >= self.regionH[k]):
                    self.r[k][n] = self.r[k][n] - self.region[k]
                elif (self.r[k][n] < -self.regionH[k]):
                    self.r[k][n] = self.r[k][n] + self.region[k]
                    
    def eval_props(self):
        self.vsum = 0.
        self.vvsum = 0.
        for n in range(int(self.natom)):
            vv = 0.
            for k in range(self.ndim):
                v = self.rv[k][n] - 0.5 * self.ra[k][n] * self.namelist['deltaT']
                self.vsum += v
                vv = vv + (v**2)
            self.vvsum += vv
        self.kinenergy = 0.5 * self.vvsum / self.natom
        self.potenergy = self.usum / self.natom
        self.totenergy = self.kinenergy + self.potenergy
        self.pressure = self.namelist['density'] * (self.vvsum + self.virsum) / (self.natom * self.ndim)
                      
    
    def display_props(self):
        print('Step: %d Energy: %0.2f' % (self.step_count, self.totenergy), end='\r')
    
    def single_step(self):
        """ Pseudo-code for single step

            def single_step():
            step_count += 1
            time_now = step_count * deltaT
            compute_forces()
            leapfrog_step()
            apply_boundary_cond()
            eval_props()

        """
        self.step_count += 1
        self.time_now = self.step_count * self.namelist['temperature']
        self.compute_forces()
        self.leapfrog_step()
        self.apply_boundary_cond()
        self.eval_props()
        self.display_props()

# %% [markdown]
# Let's visualize what happens after a single step of MD so far.
#
# Remember, this is a simple model and not a full version of MD which would encompass step prediction / correction, a thermostat (e.g. Langevin thermostat), etc.

# %%
fig, ax = plt.subplots()
test = MD('input')
test.get_name_list()
test.set_params()
test.alloc_arrays()
test.init_coords()
test.init_vels()
test.single_step()

ax.scatter(test.r[0, :], test.r[1, :], color='k')
plt.show()
# Out:
# Step: 1 Energy: 0.99

# %% [markdown]
# Let's animate the process.

# %%
from matplotlib import animation # Required class for animations
from IPython.display import HTML # Required for Jupyter Notebook display

anifig = plt.figure()
ax = plt.scatter(test.r[0, :], test.r[1, :], color='k')

def animate(i):
    test.single_step()
    ax.set_offsets(test.r.T) # update scatter data (req. transpose)
    return ax

anim = animation.FuncAnimation(anifig, animate, frames=100, interval=10)
HTML(anim.to_jshtml())
# Out:
# Step: 102 Energy: 275186269787126144.0000000
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgf41fb95e399c4ccab2c37633eefd7288">
#   <div class="anim-controls">
#     <input id="_anim_sliderf41fb95e399c4ccab2c37633eefd7288" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animf41fb95e399c4ccab2c37633eefd7288.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animf41fb95e399c4ccab2c37633eefd7288.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectf41fb95e399c4ccab2c37633eefd7288" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_f41fb95e399c4ccab2c37633eefd7288"
#              >
#       <label for="_anim_radio1_f41fb95e399c4ccab2c37633eefd7288">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_f41fb95e399c4ccab2c37633eefd7288"
#              checked>
#       <label for="_anim_radio2_f41fb95e399c4ccab2c37633eefd7288">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_f41fb95e399c4ccab2c37633eefd7288"
#              >
#       <label for="_anim_radio3_f41fb95e399c4ccab2c37633eefd7288">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgf41fb95e399c4ccab2c37633eefd7288";
#     var slider_id = "_anim_sliderf41fb95e399c4ccab2c37633eefd7288";
#     var loop_select_id = "_anim_loop_selectf41fb95e399c4ccab2c37633eefd7288";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAcjElEQVR4nO3dT2xcV9nH8ee6UZG8ApS4TWzswTgJ\
# JLFlsFvRTUGpE1BoHSEkyCJSaRCWIKsKwS5qFnESqYhVWdSKKkVNhUVRSxZNDaqEuqCI1EhekAjJ\
# CrbJH6d1kiL+SKRqfd7F65lOEifxzLkzv/PM/X4kpGbwc85zzh3fJzPn3JMshBAMAABn2tQJAABQ\
# DwoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUK\
# GADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgA\
# wCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADAJQoYAMAlChgAwCUKGADApXXqBBpl\
# /fr1ViqV1GkAgCvz8/N27do1d
# Step: 103 Energy: 232616675681757134848.00

# %% [markdown]
# To ensure we are on the right track, let's compare the distribution of velocities we acquire from our simplified MD to the Maxwell distribution using the same input values.

# %%
def f(v, d=2, T=1):
    """ Maxwell distribution approximation after "angular integration" (converting to spherical coords and integrating)
    """
    return (v**d) * np.exp(-v**2 / (2*T))

fig, ax = plt.subplots()

maxwell_dist = [f(i) for i in np.arange(0, 10, .1)]

ax.plot(maxwell_dist, lw=2, color='k')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

test = MD('input')
test.get_name_list()
test.set_params()
test.alloc_arrays()
test.init_coords()
test.init_vels()
test.single_step()

fig, ax = plt.subplots()

for i in range(int(test.namelist['stepLimit'])): # 25 steps
    dist = []
    for n in range(test.natom):
        vv = (test.rv[0][n] ** 2) + (test.rv[1][n] ** 2 ) # velocity in both directions squared and added (maxwell: exp(-v^2))
        dist.append(vv)
    sns.kdeplot(dist, lw=2, bw_adjust=3, ax=ax)
    test.single_step()
    
ax.set_xlim([0, 10])
plt.show()
# Out:
# Step: 26 Energy: 17.67

# %% [markdown]
# We are computing forces for every atom pair in the system. This would be too inefficient for production-quality molecular dynamics.

# %% [markdown]
# There are many ways to make this model more advanced (e.g. potentials (LJ) fitted to QM/experimental data, harmonic potentials for bonds between atoms, other integration algorithms, handling of long-range interactions / charge).

# %% [markdown]
# We can now easily convert the model to 3D space by modifying existing parameters and adding the z component.
#
# There is a lot more to molecular dynamics than shown here, and it is a field of study in its own right. The code can become rather extensive so care must be taken to ensure calculations are performed optimally and correctly.
#
# There are a variety of packages which can perform molecular dynamics simulations for studying various chemical systems including:
#
#     * AMBER
#     * GROMACS
#     * LAMMPS
#     * NAMD
#
# The code for these packages is written with high performance in mind and includes the previously mentioned advanced features.
